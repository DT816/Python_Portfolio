# %% [markdown]
# <h1>Document Similarity using LSI</h1>

# %%
def get_musicians(url):
    from bs4 import BeautifulSoup
    import requests
    page_soup = BeautifulSoup(requests.get(url).content,'lxml')
    li_tags = page_soup.find_all('li')
    all_musicians = list()
    for tag in li_tags:
        if tag.get('id'):
            continue

        try:
            tag.find('sup',class_="reference")
            link = tag.find('a').get('href')
            name = tag.find('a').get_text()
            if "/wiki/" in link and non_musician_finder(link):
                all_musicians.append((name,"https://en.wikipedia.org" + link))
        except:
            pass
    return all_musicians

def non_musician_finder(link):
    non_musician_words = ['Category','Template','Portal','List','File','Template','Special','Main','Help','User']
    for word in non_musician_words:
        if word in link:
            return False
    return True

# %%
url = "https://en.wikipedia.org/wiki/List_of_alternative_country_musicians"
#get_musicians(url)

# %%
def get_musician_text(url):
    from bs4 import BeautifulSoup
    import requests
    all_text = ''
    try:
        page_soup = BeautifulSoup(requests.get(url).content,'lxml')
        for p_tag in page_soup.find_all('p'):
            all_text += p_tag.get_text()
    except:
        return None
    return all_text

# %%
url = "https://en.wikipedia.org/wiki/Jim_Morrison"
#get_musician_text(url)

# %%
def get_all_musicians(genre_list):
    all_musicians = list()
    for genre in genre_list:
        url = 'https://en.wikipedia.org/wiki/List_of_' + genre
    
        #Your code here
        all_musicians.extend(get_musicians(url))
    
    return all_musicians

# %%
genre_list = ['bluegrass_musicians#G','British_blues_musicians','country_blues_musicians','emo_artists','alternative_country_musicians']
all_musicians = get_all_musicians(genre_list)
all_musicians[:5]
# Out:
# [('Tom Adams', 'https://en.wikipedia.org/wiki/Tom_Adams_(bluegrass_musician)'),
#  ('Eddie Adcock', 'https://en.wikipedia.org/wiki/Eddie_Adcock'),
#  ('David "Stringbean" Akeman',
#   'https://en.wikipedia.org/wiki/David_%22Stringbean%22_Akeman'),
#  ('Red Allen', 'https://en.wikipedia.org/wiki/Red_Allen_(bluegrass)'),
#  ('Darol Anger', 'https://en.wikipedia.org/wiki/Darol_Anger')]

# %%
def get_all_musician_docs(all_musicians):
    musician_names = list()
    musician_texts = list()
    for musician in all_musicians:
        name = musician[0]
        url = musician[1]
        
        #Your code here
        text = get_musician_text(url)
        if text == None:
            continue
        else:
            musician_names.append(name)
            musician_texts.append(text)
    return musician_names,musician_texts

# %%
reference_names,reference_docs = get_all_musician_docs(all_musicians)

# %%
#Code for LSI model goes here
from gensim.similarities.docsim import Similarity
from gensim import corpora, models, similarities
from gensim.parsing.preprocessing import STOPWORDS

texts = [[word for word in document.lower().split()
        if word not in STOPWORDS and word.isalnum()]
        for document in reference_docs]

dictionary = corpora.Dictionary(texts)#(word_id,word)
corpus = [dictionary.doc2bow(text) for text in texts]# (word_id,fequency)for each text

lsi = models.LsiModel(corpus, id2word=dictionary, num_topics=5)

# %%
musician_genre_list = ['acid_rock_artists']
all_musicians = get_all_musicians(musician_genre_list)
musician_names,musician_docs = get_all_musician_docs(all_musicians)

# %%
table_data = list()
for index,musician in enumerate(musician_docs):
    
    #Your similarity code here. Use the in-class notebook as a reference
    vec_bow = dictionary.doc2bow(musician.lower().split())
    vec_lsi = lsi[vec_bow]
    index_fun = similarities.MatrixSimilarity(lsi[corpus])
    sims = index_fun[vec_lsi]
    sims = sorted(enumerate(sims), key=lambda item: -item[1])
    
    most_similar_musician = sims[0][0]
    table_data.append((musician_names[index],reference_names[most_similar_musician]))
    
#Write code to print table_data after the for loop ends
import pandas as pd
df = pd.DataFrame(table_data, columns=['Musician', 'Most Similar Musician'])

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
df
# Out:
#                                 Musician  \
# 0               The 13th Floor Elevators
# 1                           Alice Cooper
# 2                        The Amboy Dukes
# 3                              Amon Düül
# 4    Big Brother and the Holding Company
# 5                          Black Sabbath
# 6                             Blue Cheer
# 7                           Blues Magoos
# 8                         The Charlatans
# 9                             Count Five
# 10              Country Joe and the Fish
# 11                                 Coven
# 12                                 Cream
# 13                           Deep Purple
# 14                          The Deviants
# 15                             The Doors
# 16                   The Electric Prunes
# 17                              The Fugs
# 18                         Grateful Dead
# 19                     The Great Society
# 20                        The Groundhogs
# 21                              Hawkwind
# 22                        Iron Butterfly
# 23                    Jefferson Airplane
# 24           The Jimi Hendrix Experience
# 25                          Janis Joplin
# 26                        JPT Scare Band
# 27                                  Love
# 28                                   MC5
# 29                            Moby Grape
# 30                     The Music Machine
# 31         Quicksilver Messenger Service
# 32                               Santana
# 33                             The Seeds
# 34                           Grace Slick
# 35                           Steppenwolf
# 36                                 Tully
# 37                         Vanilla Fudge
# 38                         Wooden Shjips
# 39                             Acid rock
# 40                  Knowles, Christopher
# 41                        McIntyre, Iain
# 42                           Prown, Pete
# 43                                  Folk
# 44                     New Weird America
# 45                                  Funk
# 46                                   Pop
# 47                                  Rock
# 48                                  Soul
# 49                        Cinematic soul
# 50                                Trance
# 51                            Goa trance
# 52                             Nitzhonot
# 53                                Psydub
# 54                           Suomisaundi
# 55                                 House
# 56                                  Jazz
# 57                                  Punk
# 58                                  Rock
# 59                                Techno
# 60                                Trance
# 61                             Chillwave
# 62                            Dream-beat
# 63                             Freakbeat
# 64                        Hypnagogic pop
# 65            Italian occult psychedelia
# 66                             Krautrock
# 67                            Madchester
# 68                       Neo-psychedelia
# 69                             Dream pop
# 70                              Shoegaze
# 71                   Paisley Underground
# 72                           Sampledelia
# 73                            Space rock
# 74                           Stoner rock
# 75                            Tropicália
# 76                               Zamrock
# 77                       Beat Generation
# 78                      Cannabis culture
# 79           Counterculture of the 1960s
# 80                              Deadhead
# 81                           Freak scene
# 82                                 Grebo
# 83                               Hippies
# 84                              Jam band
# 85                    New Age travellers
# 86                          Rave culture
# 87                   San Francisco Sound
# 88                 Second Summer of Love
# 89                        Summer of Love
# 90                        UK underground
# 91                     Palm Desert Scene
# 92                        History of LSD
# 93                      New Age movement
# 94                     Progressive music
# 95                           Psychedelia
# 96                       Psychedelic art
# 97                               LSD art
# 98                      Psychedelic drug
# 99                       Psychedelic era
# 100               Psychedelic experience
# 101               Psychedelic literature
# 102               Sitar in popular music
#
#                           Most Similar Musician
# 0                                  Fragile Rock
# 1                              The Spill Canvas
# 2                                   Joan of Arc
# 3                                   Water Liars
# 4                             The Pretty Things
# 5                               The Anniversary
# 6                               Jeff Beck Group
# 7                                 Pink Anderson
# 8                               Drive Like Jehu
# 9                                  Tommy Ramone
# 10                                 Robbie Fulks
# 11                               Marcus Mumford
# 12                                        Cream
# 13                                         Nude
# 14                                         Nude
# 15                            The Pretty Things
# 16                           The Bottle Rockets
# 17                            The Pretty Things
# 18                           The Bottle Rockets
# 19                                 Wishbone Ash
# 20                               The Groundhogs
# 21                                 Wishbone Ash
# 22                                  Steamhammer
# 23                                         Free
# 24                  The Jimi Hendrix Experience
# 25                                 Led Zeppelin
# 26                              Blitzen Trapper
# 27                                   Whitesnake
# 28                                 Fragile Rock
# 29                                   Jay Farrar
# 30                       Old Crow Medicine Show
# 31                            The Pretty Things
# 32                                   Whitesnake
# 33                                         Free
# 34                              Vassar Clements
# 35                                  Chris Thile
# 36                                   Native Nod
# 37                            American Football
# 38                       Old Crow Medicine Show
# 39                               Dennis Fetchet
# 40                                   Top Topham
# 41                                     Sam Bush
# 42                                     Don Reno
# 43                                   Kaia Kater
# 44                               Old-time music
# 45                                 Tony Furtado
# 46                                    Merlefest
# 47                        Kenny Baker (fiddler)
# 48                                  Bob Brozman
# 49                                 Andy Statman
# 50                                    Crunkcore
# 51                               Old-time music
# 52                               Jim Lauderdale
# 53                                      Emo rap
# 54                                Mark O'Connor
# 55                               Russ Barenberg
# 56                                         Jazz
# 57                                   Work songs
# 58                               Dennis Fetchet
# 59                                    technique
# 60   International Bluegrass Music Hall of Fame
# 61                                 Bill Clifton
# 62                                   Work songs
# 63                                Andy Griffith
# 64                                Larkin, Colin
# 65    International Bluegrass Music Association
# 66                                Larkin, Colin
# 67                                    Rico Bell
# 68                                   Work songs
# 69                       Old Crow Medicine Show
# 70                             Rhiannon Giddens
# 71                              Drive Like Jehu
# 72                                Larkin, Colin
# 73                       Robert Palmer (singer)
# 74                              Drive Like Jehu
# 75                              Greenwald, Andy
# 76                                 Benny Martin
# 77                          Spencer Davis Group
# 78                                Boogie-woogie
# 79                                 Tony Furtado
# 80                                 Fragile Rock
# 81                              Brennan Gilmore
# 82                                  Kenny Kosek
# 83                             Washington, D.C.
# 84                            The Waco Brothers
# 85                                   New Jersey
# 86                                    Crunkcore
# 87                                 Tony Furtado
# 88                                    Crunkcore
# 89                             Rhiannon Giddens
# 90                                 The Dillards
# 91                        Kenny Baker (fiddler)
# 92                                Charlie Cline
# 93                                   New Jersey
# 94                                    Crunkcore
# 95                                   Work songs
# 96                             John Byrne Cooke
# 97                              Carl Rutherford
# 98                                  Midwest emo
# 99                                Walter Roland
# 100                                 Midwest emo
# 101                                   Bo Carter
# 102                              David Bromberg
